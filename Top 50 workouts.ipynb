# %%
# top 50 exercise for the body import from excel 
import pandas

# %%
dataset = pandas.read_csv("Top 50 Excerice for your body.csv")

# %%
import pandas as pd

# %%
dataset = pd.read_csv ("Top 50 Excerice for your body.csv")

# %%
dataset.head(10)
# Out:
#     Name of Exercise  Sets  Reps  \
# 0           Push-ups     3    15
# 1             Squats     4    12
# 2             Lunges     3    10
# 3            Burpees     3    10
# 4  Mountain Climbers     3    20
# 5      Jumping Jacks     3    30
# 6   Bicycle Crunches     3    20
# 7               Dips     3    12
# 8           Pull-ups     3     8
# 9     Russian Twists     3    20
#
#                                            Benefit  \
# 0                       Builds upper body strength
# 1                           Strengthens lower body
# 2                Improves balance and coordination
# 3                                Full body workout
# 4                  Improves cardiovascular fitness
# 5  Improves coordination and cardiovascular health
# 6                        Targets abdominal muscles
# 7                    Strengthens triceps and chest
# 8                       Builds upper body strength
# 9                  Improves core rotation strength
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name of Exercise             50 non-null     object
#  1   Sets                         50 non-null     int64
#  2   Reps                         50 non-null     int64
#  3   Benefit                      50 non-null     object
#  4   Burns Calories (per 30 min)  50 non-null     int64
#  5   Target Muscle Group          50 non-null     object
#  6   Equipment Needed             30 non-null     object
#  7   Difficulty Level             50 non-null     object
# dtypes: int64(3), object(5)
# memory usage: 3.3+ KB

# %%
dataset.describe()
# Out:
#             Sets       Reps  Burns Calories (per 30 min)
# count  50.000000  50.000000                    50.000000
# mean    3.120000  12.780000                   229.960000
# std     0.328261   4.559314                    58.896991
# min     3.000000   5.000000                   130.000000
# 25%     3.000000  10.000000                   180.000000
# 50%     3.000000  12.000000                   221.500000
# 75%     3.000000  15.000000                   278.750000
# max     4.000000  30.000000                   355.000000
